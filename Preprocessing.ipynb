# %% [markdown]
# <a href="https://colab.research.google.com/github/chaitraDev/GenAI-for-marketing/blob/main/Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import statistics as stat

# %%
ds = pd.read_excel("/content/customers_segmented_p2.xlsx")

# %%
ds.columns
# Out:
# Index(['Unnamed: 0', 'CustomerID', 'CustGender', 'CustLocation',
#        'CustAccountBalance', 'most_recent', 'Gap', 'Num_Transactions',
#        'Sum_Transactions', 'Recency', 'Monetary_Value', 'Frequency',
#        'RFM_Score', 'Relationship_Value', 'Age', 'Cibil_Score', 'Income',
#        'Product'],
#       dtype='object')

# %%
ds.isnull().sum()
# Out:
# Unnamed: 0               0
# CustomerID               0
# CustGender             540
# CustLocation            87
# CustAccountBalance    1194
# most_recent              0
# Gap                      0
# Num_Transactions         0
# Sum_Transactions         0
# Recency                  0
# Monetary_Value           0
# Frequency                0
# RFM_Score                0
# Relationship_Value       0
# Age                      0
# Cibil_Score              0
# Income                   0
# Product                  0
# dtype: int64

# %%
#ds["CustomerDOB"] = pd.to_datetime(ds.CustomerDOB, format='mixed').dt.date

# %%
#years = ([DOB.year for DOB in ds['CustomerDOB']])
#med_year = stat.median(years)
#med_year

# %%
#curr_year = pd.Timestamp.now().year
#med_age = curr_year - med_year
#ds['Age'].fillna(value=med_age, inplace = True)

# %%
mode_gender = ds['CustGender'].mode()[0]

# %%
ds['CustGender'].fillna(mode_gender, inplace= True)

# %%
ds.isnull().sum()
# Out:
# Unnamed: 0               0
# CustomerID               0
# CustGender               0
# CustLocation            87
# CustAccountBalance    1194
# most_recent              0
# Gap                      0
# Num_Transactions         0
# Sum_Transactions         0
# Recency                  0
# Monetary_Value           0
# Frequency                0
# RFM_Score                0
# Relationship_Value       0
# Age                      0
# Cibil_Score              0
# Income                   0
# Product                  0
# dtype: int64

# %%
mode_location = ds['CustLocation'].mode()[0]

# %%
ds['CustLocation'].fillna(mode_location, inplace=True)

# %%
#ds.drop(columns = ['CustomerDOB'], inplace = True)

# %%
ds.columns
# Out:
# Index(['Unnamed: 0', 'CustomerID', 'CustGender', 'CustLocation',
#        'CustAccountBalance', 'most_recent', 'Gap', 'Num_Transactions',
#        'Sum_Transactions', 'Recency', 'Monetary_Value', 'Frequency',
#        'RFM_Score', 'Relationship_Value', 'Age', 'Cibil_Score', 'Income',
#        'Product'],
#       dtype='object')

# %%
ds.isnull().sum()
# Out:
# Unnamed: 0               0
# CustomerID               0
# CustGender               0
# CustLocation             0
# CustAccountBalance    1194
# most_recent              0
# Gap                      0
# Num_Transactions         0
# Sum_Transactions         0
# Recency                  0
# Monetary_Value           0
# Frequency                0
# RFM_Score                0
# Relationship_Value       0
# Age                      0
# Cibil_Score              0
# Income                   0
# Product                  0
# dtype: int64

# %%
ds.drop(columns  = ['CustAccountBalance'], inplace= True)

# %%
from sklearn import preprocessing

# %%
l_e = preprocessing.LabelEncoder()

# %%
ds['Relation_Value'] = l_e.fit_transform(ds['Relationship_Value'])

# %%
ds.columns
# Out:
# Index(['Unnamed: 0', 'CustomerID', 'CustGender', 'CustLocation', 'most_recent',
#        'Gap', 'Num_Transactions', 'Sum_Transactions', 'Recency',
#        'Monetary_Value', 'Frequency', 'RFM_Score', 'Relationship_Value', 'Age',
#        'Cibil_Score', 'Income', 'Product', 'Relation_Value'],
#       dtype='object')

# %%
print(ds['Relationship_Value'].head())
# Out:
# 0    high
# 1     low
# 2     low
# 3     low
# 4     low
# Name: Relationship_Value, dtype: object

# %%
ds['CustomerGender'] = l_e.fit_transform(ds['CustGender'])

# %%
ds['CustLocation'] = ds['CustLocation'].astype(str)
ds["CustomerLocation"] = l_e.fit_transform(ds['CustLocation'])

# %%
ds['Product_list'] = l_e.fit_transform(ds['Product'])

# %%
ds
# Out:
#         Unnamed: 0 CustomerID CustGender            CustLocation most_recent  \
# 0                0   C5110785          M                 GURGAON  2016-09-26
# 1                1   C4893113          M                 LUCKNOW  2016-03-08
# 2                2   C8539146          F                    DURG  2016-02-08
# 3                3   C2039160          F                    DURG  2016-02-08
# 4                4   C2131351          F                   DELHI  2016-02-08
# ...            ...        ...        ...                     ...         ...
# 539486      539486   C2119451          M                 PANIPAT  2016-08-27
# 539487      539487   C2637931          M                   DELHI  2016-08-28
# 539488      539488   C7031823          M  S O MUMBAI MULUND WEST  2016-08-09
# 539489      539489   C7437941          M                   DELHI  2016-10-09
# 539490      539490   C3337911          M                   DELHI  2016-10-09
#
# ...
