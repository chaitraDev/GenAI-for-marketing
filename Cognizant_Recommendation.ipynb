# %% [markdown]
# <a href="https://colab.research.google.com/github/chaitraDev/GenAI-for-marketing/blob/main/Cognizant_Recommendation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import joblib
model = joblib.load("/content/kmeans1 (2).pkl")

# %%
import pandas as pd
customers = pd.read_excel("/content/drive/MyDrive/Cognizant/cust_segmented_clustered_nonum.xlsx")

# %%
customers.columns
# Out:
# Index(['CustomerID', 'Age', 'Cibil_Score', 'Income', 'Product', 'Clusters'], dtype='object')

# %%
def get_customers(product_name):
  # Find the clusters that have this product
  clusters = customers[customers.Product == product_name].Clusters.unique()
  prod_index = customers[customers.Product == product_name].index

  # Find how many times the product has appeared in those clusters
  cluster_product = customers.loc[:,["Clusters","Product"]]
  mapping = {cluster:0 for cluster in clusters}
  for index in prod_index:
    cluster_no = cluster_product.iloc[index]["Clusters"]
    mapping[cluster_no] += 1
  print(mapping)

  # find the cluster that has this product max number of times
  best_cluster = sorted(mapping.items(),key=lambda pair:pair[1],reverse=True)[0][0]

  # Find the customers that belong to this cluster and aren't using this product
  targets = customers[((customers.Clusters == best_cluster) & (customers.Product!=product_name))]
  return targets

# %%
get_customers("National_Pension_System")
# Out:
# {40: 980, 21: 977, 32: 821, 5: 560, 28: 455, 46: 1125}
#       CustomerID  Age  Cibil_Score   Income                           Product  \
# 33      C6931388   94          502   200.00  Senior Citizens Health Insurance
# 35      C5331380   94          445   300.00  Senior Citizens Health Insurance
# 55      C2514473   93          517   134.00  Senior Citizens Health Insurance
# 60      C7625952   93          601   731.00  Senior Citizens Health Insurance
# 63      C4014424   93          673  1973.00  Senior Citizens Health Insurance
# ...          ...  ...          ...      ...                               ...
# 39066   C2512327   52          496   510.00                 Recurring_Deposit
# 40021   C6532858   52          494   899.00                 Recurring_Deposit
# 41254   C5450883   52          483   747.51                 Recurring_Deposit
# 41423   C8822231   52          497  6332.00                 Recurring_Deposit
# ...

# %%
prod_index = customers[customers.Product == "National_Pension_System"].index

# %%
# Find how many times the product has appeared in those clusters
cluster_product = customers.loc[:,["Clusters","Product"]]

# %%
mapping = {cluster:0 for cluster in clusters}
for index in prod_index:
  # print(index)
  cluster_no = cluster_product.iloc[index]["Clusters"]
  mapping[cluster_no] += 1
mapping
# Out:
# {40: 980, 21: 977, 32: 821, 5: 560, 28: 455, 46: 1125}

# %%
sorted(mapping.items(),key=lambda pair:pair[1],reverse=True)[0][0]
# Out:
# 46

# %%
# Find the customers that belong to this cluster and aren't using this product
targets = customers[((customers.Clusters == 46) & (customers.Product!="National_Pension_System"))]
targets
# Out:
#       CustomerID  Age  Cibil_Score   Income                           Product  \
# 33      C6931388   94          502   200.00  Senior Citizens Health Insurance
# 35      C5331380   94          445   300.00  Senior Citizens Health Insurance
# 55      C2514473   93          517   134.00  Senior Citizens Health Insurance
# 60      C7625952   93          601   731.00  Senior Citizens Health Insurance
# 63      C4014424   93          673  1973.00  Senior Citizens Health Insurance
# ...          ...  ...          ...      ...                               ...
# 39066   C2512327   52          496   510.00                 Recurring_Deposit
# 40021   C6532858   52          494   899.00                 Recurring_Deposit
# 41254   C5450883   52          483   747.51                 Recurring_Deposit
# 41423   C8822231   52          497  6332.00                 Recurring_Deposit
# 42344   C1513270   52          490   145.00                 Recurring_Deposit
#
#        Clusters
# ...

# %%
targets.shape
# Out:
# (2423, 6)

# %%
targets.Product.unique()
# Out:
# array(['Senior Citizens Health Insurance', 'Saving Account',
#        'Travel Insurance', 'Recurring_Deposit', 'Mutual Funds',
#        'Vehicle/Motor_Insurance'], dtype=object)
